# %%
import pandas as pd
import numpy as np

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Chargement des données (exemple avec le dataset Titanic disponible dans Seaborn)
df = sns.load_dataset('titanic')

# Affichage des premières lignes des données pour voir à quoi elles ressemblent
print(df.head())

# Définir le style des graphiques Seaborn
sns.set(style="whitegrid")

# 1. Histogramme de la répartition des âges
plt.figure(figsize=(8, 6))
sns.histplot(df['age'].dropna(), bins=30, kde=True, color='blue')
plt.title("Répartition des âges")
plt.xlabel("Âge")
plt.ylabel("Fréquence")
plt.show()

# 2. Boxplot pour montrer la répartition des âges en fonction du sexe
plt.figure(figsize=(8, 6))
sns.boxplot(x='sex', y='age', data=df)
plt.title("Répartition des âges par sexe")
plt.xlabel("Sexe")
plt.ylabel("Âge")
plt.show()

# 3. Nuage de points (scatter plot) montrant la relation entre l'âge et le prix du billet
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='fare', hue='sex', data=df)
plt.title("Relation entre l'âge et le prix du billet")
plt.xlabel("Âge")
plt.ylabel("Prix du billet")
plt.show()

# 4. Diagramme en barres montrant la répartition des classes par sexe
plt.figure(figsize=(8, 6))
sns.countplot(x='class', hue='sex', data=df)
plt.title("Répartition des classes par sexe")
plt.xlabel("Classe")
plt.ylabel("Nombre de passagers")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
